# %% [markdown]
# # DICOM Basics with pydicom
# Run a cell with a path variable to your DICOM file.

# %%
import pydicom
path='path/to/file.dcm' # <- change this
ds=pydicom.dcmread(path)
getattr(ds,'PatientID','NA'), getattr(ds,'Modality','NA'), getattr(ds,'Rows','?'), getattr(ds,'Columns','?')
